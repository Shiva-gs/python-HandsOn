# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#!pip install citipy
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests as req
import time
import random

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

url = "http://api.openweathermap.org/data/2.5/weather?"
#url = "http://api.openweathermap.org/data/2.5/weather?appid=api_key&units=imperial&q="
api_key
# Out:
# '79f96039da4c1b6cf773fb18a1fccf2b'

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []
city_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []

# set initial count quantities for organization
count_one = 0
set_one = 1


# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
cities[0]
cnt=0
for city in cities:
    print(city)
    cnt = cnt+1
    if cnt ==10:
        break
# Out:
# mar del plata
# hermanus
# bathsheba
# albany
# sibu
# kenora
# virginia beach
# pevek
# yazykovo
# cockburn town

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
weather_data = []
count_one = 0
set_one = 1
ity_two = []
cloudinesses = []
dates = []
humidities = []
lats = []
lngs = []
max_temps = []
wind_speeds = []
countries = []
count_one = 0
set_one = 1


# loops for creating dataframe columns
for city in cities:
    try:
        query_url = url + "appid=" + api_key + "&q=" + city + "&units=imperial"
        response = req.get(query_url).json()
        
        cloudinesses.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidities.append(response['main']['humidity'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        max_temps.append(response['main']['temp_max'])
        wind_speeds.append(response['wind']['speed'])
        if count_one > 48:
            count_one = 1
            set_one += 1
            city_two.append(city)
        else:
            count_one += 1
            city_two.append(city)
        print(f"Processing Record {count_one} of Set {set_one} | {city}")
    except Exception:
        print("City not found. Skipping...")
print("------------------------------\nData Retrieval Completed\n------------------------------")
# Out:
# Processing Record 1 of Set 1 | mar del plata
# Processing Record 2 of Set 1 | hermanus
# Processing Record 3 of Set 1 | bathsheba
# Processing Record 4 of Set 1 | albany
# Processing Record 5 of Set 1 | sibu
# Processing Record 6 of Set 1 | kenora
# Processing Record 7 of Set 1 | virginia beach
# Processing Record 8 of Set 1 | pevek
# Processing Record 9 of Set 1 | yazykovo
# Processing Record 10 of Set 1 | cockburn town
# Processing Record 11 of Set 1 | cape town
# Processing Record 12 of Set 1 | imeni zhelyabova
# Processing Record 13 of Set 1 | filingue
# Processing Record 14 of Set 1 | butaritari
# Processing Record 15 of Set 1 | carutapera
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | sheltozero
# Processing Record 18 of Set 1 | campos
# Processing Record 19 of Set 1 | hasaki
# Processing Record 20 of Set 1 | tasgaon
# Processing Record 21 of Set 1 | castro
# Processing Record 22 of Set 1 | paso de los toros
# Processing Record 23 of Set 1 | lagoa
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | taltal
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | broome
# Processing Record 28 of Set 1 | sioux lookout
# Processing Record 29 of Set 1 | marsa matruh
# Processing Record 30 of Set 1 | steinbach
# City not found. Skipping...
# Processing Record 31 of Set 1 | ribeira grande
# Processing Record 32 of Set 1 | talnakh
# Processing Record 33 of Set 1 | sao raimundo das mangabeiras
# Processing Record 34 of Set 1 | berlevag
# Processing Record 35 of Set 1 | victoria
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | galle
# Processing Record 38 of Set 1 | hilo
# Processing Record 39 of Set 1 | lebu
# City not found. Skipping...
# Processing Record 40 of Set 1 | calabozo
# City not found. Skipping...
# Processing Record 41 of Set 1 | saint-philippe
# Processing Record 42 of Set 1 | vila franca do campo
# Processing Record 43 of Set 1 | vardo
# Processing Record 44 of Set 1 | torbay
# Processing Record 45 of Set 1 | tasiilaq
# Processing Record 46 of Set 1 | airai
# Processing Record 47 of Set 1 | pacific grove
# Processing Record 48 of Set 1 | honiara
# Processing Record 49 of Set 1 | opuwo
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | abaza
# Processing Record 3 of Set 2 | dingle
# Processing Record 4 of Set 2 | ponta do sol
# Processing Record 5 of Set 2 | qaanaaq
# Processing Record 6 of Set 2 | punta arenas
# City not found. Skipping...
# Processing Record 7 of Set 2 | mahebourg
# Processing Record 8 of Set 2 | boden
# Processing Record 9 of Set 2 | miles city
# City not found. Skipping...
# Processing Record 10 of Set 2 | barrow
# Processing Record 11 of Set 2 | guerrero negro
# City not found. Skipping...
# Processing Record 12 of Set 2 | bredasdorp
# Processing Record 13 of Set 2 | rio grande
# Processing Record 14 of Set 2 | meulaboh
# Processing Record 15 of Set 2 | mataura
# Processing Record 16 of Set 2 | vaini
# Processing Record 17 of Set 2 | tautira
# Processing Record 18 of Set 2 | tazovskiy
# Processing Record 19 of Set 2 | narsaq
# Processing Record 20 of Set 2 | natal
# City not found. Skipping...
# Processing Record 21 of Set 2 | winslow
# Processing Record 22 of Set 2 | cidreira
# Processing Record 23 of Set 2 | celestun
# Processing Record 24 of Set 2 | busselton
# Processing Record 25 of Set 2 | tiksi
# Processing Record 26 of Set 2 | baruun-urt
# Processing Record 27 of Set 2 | xining
# Processing Record 28 of Set 2 | tuatapere
# Processing Record 29 of Set 2 | bonavista
# Processing Record 30 of Set 2 | atuona
# Processing Record 31 of Set 2 | sayansk
# Processing Record 32 of Set 2 | iqaluit
# City not found. Skipping...
# Processing Record 33 of Set 2 | tuktoyaktuk
# Processing Record 34 of Set 2 | cayenne
# Processing Record 35 of Set 2 | arlit
# Processing Record 36 of Set 2 | rikitea
# Processing Record 37 of Set 2 | nome
# Processing Record 38 of Set 2 | virar
# Processing Record 39 of Set 2 | new norfolk
# Processing Record 40 of Set 2 | kruisfontein
# Processing Record 41 of Set 2 | mehamn
# Processing Record 42 of Set 2 | butembo
# Processing Record 43 of Set 2 | kapaa
# Processing Record 44 of Set 2 | carauari
# Processing Record 45 of Set 2 | katsuura
# Processing Record 46 of Set 2 | christchurch
# City not found. Skipping...
# Processing Record 47 of Set 2 | sisimiut
# Processing Record 48 of Set 2 | hambantota
# Processing Record 49 of Set 2 | sabang
# Processing Record 1 of Set 3 | teguise
# Processing Record 2 of Set 3 | tari
# Processing Record 3 of Set 3 | yerbogachen
# Processing Record 4 of Set 3 | arraial do cabo
# Processing Record 5 of Set 3 | east london
# Processing Record 6 of Set 3 | fortuna
# Processing Record 7 of Set 3 | lorengau
# Processing Record 8 of Set 3 | ostrovnoy
# Processing Record 9 of Set 3 | saku
# Processing Record 10 of Set 3 | komatipoort
# Processing Record 11 of Set 3 | zhuhai
# City not found. Skipping...
# Processing Record 12 of Set 3 | te anau
# Processing Record 13 of Set 3 | eyl
# Processing Record 14 of Set 3 | clyde river
# Processing Record 15 of Set 3 | barra
# City not found. Skipping...
# Processing Record 16 of Set 3 | alyangula
# Processing Record 17 of Set 3 | luderitz
# Processing Record 18 of Set 3 | bilibino
# Processing Record 19 of Set 3 | kyren
# Processing Record 20 of Set 3 | sfantu gheorghe
# Processing Record 21 of Set 3 | salina cruz
# Processing Record 22 of Set 3 | carnarvon
# Processing Record 23 of Set 3 | bambanglipuro
# Processing Record 24 of Set 3 | port alfred
# Processing Record 25 of Set 3 | ketchikan
# Processing Record 26 of Set 3 | padang
# Processing Record 27 of Set 3 | pechenga
# Processing Record 28 of Set 3 | sao filipe
# Processing Record 29 of Set 3 | bubaque
# Processing Record 30 of Set 3 | paamiut
# Processing Record 31 of Set 3 | provost
# Processing Record 32 of Set 3 | saint george
# Processing Record 33 of Set 3 | lerwick
# City not found. Skipping...
# Processing Record 34 of Set 3 | sawakin
# Processing Record 35 of Set 3 | masumbwe
# Processing Record 36 of Set 3 | baglan
# Processing Record 37 of Set 3 | empalme
# Processing Record 38 of Set 3 | port hedland
# Processing Record 39 of Set 3 | ahipara
# Processing Record 40 of Set 3 | kahului
# Processing Record 41 of Set 3 | saskylakh
# Processing Record 42 of Set 3 | socorro
# Processing Record 43 of Set 3 | rio gallegos
# Processing Record 44 of Set 3 | avarua
# Processing Record 45 of Set 3 | kodiak
# Processing Record 46 of Set 3 | teknaf
# Processing Record 47 of Set 3 | west bay
# Processing Record 48 of Set 3 | souillac
# City not found. Skipping...
# Processing Record 49 of Set 3 | caravelas
# Processing Record 1 of Set 4 | yenagoa
# Processing Record 2 of Set 4 | grenville
# Processing Record 3 of Set 4 | uray
# Processing Record 4 of Set 4 | saravena
# Processing Record 5 of Set 4 | cobija
# Processing Record 6 of Set 4 | san quintin
# Processing Record 7 of Set 4 | imbituba
# Processing Record 8 of Set 4 | the valley
# Processing Record 9 of Set 4 | harlingen
# Processing Record 10 of Set 4 | olinda
# Processing Record 11 of Set 4 | monrovia
# Processing Record 12 of Set 4 | okhotsk
# Processing Record 13 of Set 4 | hithadhoo
# Processing Record 14 of Set 4 | trelew
# Processing Record 15 of Set 4 | upernavik
# Processing Record 16 of Set 4 | lusaka
# Processing Record 17 of Set 4 | nikolskoye
# Processing Record 18 of Set 4 | riisipere
# Processing Record 19 of Set 4 | lyuban
# Processing Record 20 of Set 4 | great bend
# Processing Record 21 of Set 4 | hobart
# Processing Record 22 of Set 4 | nemuro
# Processing Record 23 of Set 4 | beyneu
# Processing Record 24 of Set 4 | valdivia
# Processing Record 25 of Set 4 | tabas
# Processing Record 26 of Set 4 | talas
# Processing Record 27 of Set 4 | grand gaube
# Processing Record 28 of Set 4 | grenfell
# Processing Record 29 of Set 4 | sirjan
# City not found. Skipping...
# Processing Record 30 of Set 4 | mpika
# Processing Record 31 of Set 4 | antalaha
# Processing Record 32 of Set 4 | aloleng
# City not found. Skipping...
# Processing Record 33 of Set 4 | esperance
# Processing Record 34 of Set 4 | mount gambier
# Processing Record 35 of Set 4 | saldanha
# Processing Record 36 of Set 4 | axim
# Processing Record 37 of Set 4 | lazaro cardenas
# Processing Record 38 of Set 4 | khatanga
# Processing Record 39 of Set 4 | antofagasta
# Processing Record 40 of Set 4 | laguna
# Processing Record 41 of Set 4 | nizhniy kuranakh
# Processing Record 42 of Set 4 | kavieng
# Processing Record 43 of Set 4 | araouane
# Processing Record 44 of Set 4 | ewa beach
# City not found. Skipping...
# Processing Record 45 of Set 4 | kobryn
# Processing Record 46 of Set 4 | provideniya
# Processing Record 47 of Set 4 | amapa
# Processing Record 48 of Set 4 | nabire
# Processing Record 49 of Set 4 | pangnirtung
# Processing Record 1 of Set 5 | port lincoln
# Processing Record 2 of Set 5 | pisco
# Processing Record 3 of Set 5 | alice springs
# Processing Record 4 of Set 5 | puerto asis
# Processing Record 5 of Set 5 | nikki
# Processing Record 6 of Set 5 | isangel
# Processing Record 7 of Set 5 | leshukonskoye
# Processing Record 8 of Set 5 | palmer
# Processing Record 9 of Set 5 | warrington
# Processing Record 10 of Set 5 | pochinki
# Processing Record 11 of Set 5 | zhigansk
# Processing Record 12 of Set 5 | lavrentiya
# Processing Record 13 of Set 5 | guigue
# Processing Record 14 of Set 5 | smithers
# Processing Record 15 of Set 5 | pochutla
# Processing Record 16 of Set 5 | kalangala
# Processing Record 17 of Set 5 | nikolayevka
# Processing Record 18 of Set 5 | liwale
# Processing Record 19 of Set 5 | kasongo
# Processing Record 20 of Set 5 | lianzhou
# Processing Record 21 of Set 5 | aripuana
# Processing Record 22 of Set 5 | aklavik
# Processing Record 23 of Set 5 | itarema
# City not found. Skipping...
# Processing Record 24 of Set 5 | ulladulla
# Processing Record 25 of Set 5 | kaitangata
# Processing Record 26 of Set 5 | nushki
# Processing Record 27 of Set 5 | kaka
# Processing Record 28 of Set 5 | port-cartier
# Processing Record 29 of Set 5 | codrington
# Processing Record 30 of Set 5 | sokoni
# Processing Record 31 of Set 5 | gat
# Processing Record 32 of Set 5 | gardner
# Processing Record 33 of Set 5 | margate
# Processing Record 34 of Set 5 | nouadhibou
# Processing Record 35 of Set 5 | elur
# Processing Record 36 of Set 5 | constitucion
# Processing Record 37 of Set 5 | ahvaz
# Processing Record 38 of Set 5 | leningradskiy
# Processing Record 39 of Set 5 | waingapu
# Processing Record 40 of Set 5 | georgetown
# Processing Record 41 of Set 5 | jalingo
# Processing Record 42 of Set 5 | nouakchott
# Processing Record 43 of Set 5 | iwanai
# Processing Record 44 of Set 5 | namatanai
# Processing Record 45 of Set 5 | port elizabeth
# Processing Record 46 of Set 5 | itoman
# Processing Record 47 of Set 5 | adrar
# City not found. Skipping...
# Processing Record 48 of Set 5 | zaranj
# Processing Record 49 of Set 5 | college
# Processing Record 1 of Set 6 | portland
# City not found. Skipping...
# Processing Record 2 of Set 6 | bestobe
# Processing Record 3 of Set 6 | san patricio
# Processing Record 4 of Set 6 | salalah
# Processing Record 5 of Set 6 | dunedin
# Processing Record 6 of Set 6 | mana
# City not found. Skipping...
# Processing Record 7 of Set 6 | issoire
# Processing Record 8 of Set 6 | abomey
# Processing Record 9 of Set 6 | talant
# Processing Record 10 of Set 6 | xai-xai
# Processing Record 11 of Set 6 | saint-pierre
# Processing Record 12 of Set 6 | tecpan
# Processing Record 13 of Set 6 | henties bay
# Processing Record 14 of Set 6 | nantucket
# Processing Record 15 of Set 6 | staunton
# City not found. Skipping...
# Processing Record 16 of Set 6 | lowestoft
# Processing Record 17 of Set 6 | bulawayo
# Processing Record 18 of Set 6 | sitka
# Processing Record 19 of Set 6 | waddan
# Processing Record 20 of Set 6 | norman wells
# Processing Record 21 of Set 6 | conceicao da barra
# Processing Record 22 of Set 6 | osypenko
# Processing Record 23 of Set 6 | noumea
# Processing Record 24 of Set 6 | la ronge
# Processing Record 25 of Set 6 | saint-michel-des-saints
# Processing Record 26 of Set 6 | tokmak
# Processing Record 27 of Set 6 | ikwiriri
# Processing Record 28 of Set 6 | marsh harbour
# Processing Record 29 of Set 6 | lompoc
# Processing Record 30 of Set 6 | evensk
# Processing Record 31 of Set 6 | banda aceh
# Processing Record 32 of Set 6 | fairfield
# Processing Record 33 of Set 6 | moussoro
# Processing Record 34 of Set 6 | barcelos
# Processing Record 35 of Set 6 | buraydah
# Processing Record 36 of Set 6 | doha
# Processing Record 37 of Set 6 | kiunga
# Processing Record 38 of Set 6 | yar-sale
# Processing Record 39 of Set 6 | morgan city
# Processing Record 40 of Set 6 | olga
# Processing Record 41 of Set 6 | huarmey
# Processing Record 42 of Set 6 | ridgecrest
# Processing Record 43 of Set 6 | monforte de lemos
# Processing Record 44 of Set 6 | sao jose da coroa grande
# Processing Record 45 of Set 6 | bay roberts
# Processing Record 46 of Set 6 | naron
# Processing Record 47 of Set 6 | byron bay
# Processing Record 48 of Set 6 | uige
# Processing Record 49 of Set 6 | sola
# Processing Record 1 of Set 7 | novyy urgal
# Processing Record 2 of Set 7 | aykhal
# Processing Record 3 of Set 7 | dikson
# Processing Record 4 of Set 7 | hohhot
# Processing Record 5 of Set 7 | mopti
# Processing Record 6 of Set 7 | longyearbyen
# Processing Record 7 of Set 7 | kavaratti
# Processing Record 8 of Set 7 | srednekolymsk
# Processing Record 9 of Set 7 | road town
# Processing Record 10 of Set 7 | gatehouse of fleet
# Processing Record 11 of Set 7 | szydlowiec
# Processing Record 12 of Set 7 | poum
# City not found. Skipping...
# Processing Record 13 of Set 7 | sehithwa
# Processing Record 14 of Set 7 | severo-kurilsk
# Processing Record 15 of Set 7 | thompson
# Processing Record 16 of Set 7 | russell
# Processing Record 17 of Set 7 | oranjemund
# Processing Record 18 of Set 7 | bhadasar
# Processing Record 19 of Set 7 | cabo san lucas
# Processing Record 20 of Set 7 | kapit
# Processing Record 21 of Set 7 | klaksvik
# Processing Record 22 of Set 7 | micheweni
# City not found. Skipping...
# Processing Record 23 of Set 7 | bumba
# Processing Record 24 of Set 7 | demidov
# Processing Record 25 of Set 7 | bandarbeyla
# Processing Record 26 of Set 7 | reftinskiy
# Processing Record 27 of Set 7 | bambous virieux
# Processing Record 28 of Set 7 | hami
# Processing Record 29 of Set 7 | tomatlan
# City not found. Skipping...
# Processing Record 30 of Set 7 | mohgaon
# Processing Record 31 of Set 7 | alofi
# Processing Record 32 of Set 7 | rantepao
# Processing Record 33 of Set 7 | romitan
# Processing Record 34 of Set 7 | bethel
# Processing Record 35 of Set 7 | nsanje
# Processing Record 36 of Set 7 | along
# Processing Record 37 of Set 7 | lichinga
# Processing Record 38 of Set 7 | lima
# Processing Record 39 of Set 7 | maun
# Processing Record 40 of Set 7 | nevsehir
# Processing Record 41 of Set 7 | bandundu
# Processing Record 42 of Set 7 | tarko-sale
# Processing Record 43 of Set 7 | naze
# City not found. Skipping...
# Processing Record 44 of Set 7 | kamenka
# Processing Record 45 of Set 7 | chuy
# Processing Record 46 of Set 7 | chokurdakh
# Processing Record 47 of Set 7 | ust-charyshskaya pristan
# Processing Record 48 of Set 7 | vila velha
# Processing Record 49 of Set 7 | syamzha
# Processing Record 1 of Set 8 | puhja
# Processing Record 2 of Set 8 | vilhena
# Processing Record 3 of Set 8 | itaquyry
# Processing Record 4 of Set 8 | havre-saint-pierre
# Processing Record 5 of Set 8 | brunico
# Processing Record 6 of Set 8 | douentza
# Processing Record 7 of Set 8 | ayr
# Processing Record 8 of Set 8 | horki
# Processing Record 9 of Set 8 | mayumba
# City not found. Skipping...
# Processing Record 10 of Set 8 | alta floresta
# City not found. Skipping...
# Processing Record 11 of Set 8 | angoche
# Processing Record 12 of Set 8 | ust-nera
# Processing Record 13 of Set 8 | lac-megantic
# Processing Record 14 of Set 8 | bilma
# Processing Record 15 of Set 8 | severo-yeniseyskiy
# Processing Record 16 of Set 8 | moree
# City not found. Skipping...
# Processing Record 17 of Set 8 | salinopolis
# Processing Record 18 of Set 8 | zhangjiakou
# Processing Record 19 of Set 8 | nanortalik
# Processing Record 20 of Set 8 | tecoanapa
# Processing Record 21 of Set 8 | oistins
# Processing Record 22 of Set 8 | hualmay
# Processing Record 23 of Set 8 | ancud
# Processing Record 24 of Set 8 | roald
# Processing Record 25 of Set 8 | sumenep
# Processing Record 26 of Set 8 | port macquarie
# Processing Record 27 of Set 8 | hovd
# Processing Record 28 of Set 8 | cordeiro
# Processing Record 29 of Set 8 | isla mujeres
# Processing Record 30 of Set 8 | monkey bay
# Processing Record 31 of Set 8 | paracuru
# Processing Record 32 of Set 8 | amazar
# Processing Record 33 of Set 8 | namibe
# Processing Record 34 of Set 8 | balkanabat
# City not found. Skipping...
# Processing Record 35 of Set 8 | tual
# Processing Record 36 of Set 8 | emerald
# Processing Record 37 of Set 8 | lasa
# Processing Record 38 of Set 8 | bristol
# City not found. Skipping...
# Processing Record 39 of Set 8 | meadow lake
# City not found. Skipping...
# Processing Record 40 of Set 8 | bulembu
# Processing Record 41 of Set 8 | san pedro
# Processing Record 42 of Set 8 | aljezur
# Processing Record 43 of Set 8 | santiago del estero
# Processing Record 44 of Set 8 | puerto escondido
# Processing Record 45 of Set 8 | quelimane
# Processing Record 46 of Set 8 | faanui
# Processing Record 47 of Set 8 | pascagoula
# Processing Record 48 of Set 8 | san cristobal
# Processing Record 49 of Set 8 | filadelfia
# Processing Record 1 of Set 9 | kangaatsiaq
# Processing Record 2 of Set 9 | mahajanga
# Processing Record 3 of Set 9 | rybnaya sloboda
# Processing Record 4 of Set 9 | sapa
# Processing Record 5 of Set 9 | ellensburg
# Processing Record 6 of Set 9 | kuna
# Processing Record 7 of Set 9 | solnechnyy
# Processing Record 8 of Set 9 | sinnar
# Processing Record 9 of Set 9 | vagamo
# Processing Record 10 of Set 9 | hofn
# Processing Record 11 of Set 9 | panguipulli
# Processing Record 12 of Set 9 | pine bluff
# Processing Record 13 of Set 9 | marseille
# Processing Record 14 of Set 9 | cururupu
# Processing Record 15 of Set 9 | teya
# Processing Record 16 of Set 9 | nakamura
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 17 of Set 9 | coracao de maria
# Processing Record 18 of Set 9 | bushehr
# Processing Record 19 of Set 9 | mandeville
# Processing Record 20 of Set 9 | necochea
# Processing Record 21 of Set 9 | grindavik
# Processing Record 22 of Set 9 | estacion coahuila
# Processing Record 23 of Set 9 | carquefou
# Processing Record 24 of Set 9 | coahuayana
# Processing Record 25 of Set 9 | goderich
# Processing Record 26 of Set 9 | kargil
# Processing Record 27 of Set 9 | kiama
# Processing Record 28 of Set 9 | balaguer
# Processing Record 29 of Set 9 | beringovskiy
# Processing Record 30 of Set 9 | kenai
# Processing Record 31 of Set 9 | santa cruz
# Processing Record 32 of Set 9 | peace river
# Processing Record 33 of Set 9 | biak
# Processing Record 34 of Set 9 | shubarshi
# Processing Record 35 of Set 9 | huilong
# Processing Record 36 of Set 9 | bintulu
# Processing Record 37 of Set 9 | palu
# Processing Record 38 of Set 9 | jermuk
# City not found. Skipping...
# Processing Record 39 of Set 9 | port-gentil
# Processing Record 40 of Set 9 | saltillo
# Processing Record 41 of Set 9 | ozu
# Processing Record 42 of Set 9 | corinth
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 43 of Set 9 | papara
# Processing Record 44 of Set 9 | dali
# Processing Record 45 of Set 9 | kurilsk
# City not found. Skipping...
# Processing Record 46 of Set 9 | lata
# Processing Record 47 of Set 9 | kargopol
# Processing Record 48 of Set 9 | muros
# Processing Record 49 of Set 9 | umm kaddadah
# Processing Record 1 of Set 10 | ust-ilimsk
# Processing Record 2 of Set 10 | vanderhoof
# Processing Record 3 of Set 10 | coquimbo
# Processing Record 4 of Set 10 | santa isabel do rio negro
# Processing Record 5 of Set 10 | jiaohe
# Processing Record 6 of Set 10 | saint anthony
# City not found. Skipping...
# Processing Record 7 of Set 10 | vila
# Processing Record 8 of Set 10 | portree
# Processing Record 9 of Set 10 | san jeronimo
# Processing Record 10 of Set 10 | comodoro rivadavia
# Processing Record 11 of Set 10 | bismarck
# City not found. Skipping...
# Processing Record 12 of Set 10 | saryozek
# Processing Record 13 of Set 10 | tamiahua
# Processing Record 14 of Set 10 | mier
# Processing Record 15 of Set 10 | belousovka
# Processing Record 16 of Set 10 | rapid valley
# Processing Record 17 of Set 10 | damara
# Processing Record 18 of Set 10 | jamkhed
# Processing Record 19 of Set 10 | hamilton
# Processing Record 20 of Set 10 | maldonado
# Processing Record 21 of Set 10 | nipawin
# Processing Record 22 of Set 10 | matara
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 23 of Set 10 | danielskuil
# Processing Record 24 of Set 10 | daesti
# Processing Record 25 of Set 10 | touros
# Processing Record 26 of Set 10 | madison heights
# Processing Record 27 of Set 10 | kulhudhuffushi
# Processing Record 28 of Set 10 | kargasok
# Processing Record 29 of Set 10 | hit
# Processing Record 30 of Set 10 | muhos
# City not found. Skipping...
# Processing Record 31 of Set 10 | fairbanks
# Processing Record 32 of Set 10 | komsomolskiy
# Processing Record 33 of Set 10 | nanlong
# Processing Record 34 of Set 10 | inhambane
# Processing Record 35 of Set 10 | razole
# Processing Record 36 of Set 10 | mayo
# Processing Record 37 of Set 10 | manono
# Processing Record 38 of Set 10 | jian
# Processing Record 39 of Set 10 | buala
# City not found. Skipping...
# Processing Record 40 of Set 10 | lakatoro
# Processing Record 41 of Set 10 | gigmoto
# Processing Record 42 of Set 10 | anadyr
# Processing Record 43 of Set 10 | wuwei
# Processing Record 44 of Set 10 | matamoros
# Processing Record 45 of Set 10 | hayden
# Processing Record 46 of Set 10 | qarqin
# Processing Record 47 of Set 10 | san juan
# Processing Record 48 of Set 10 | qasigiannguit
# Processing Record 49 of Set 10 | yeppoon
# Processing Record 1 of Set 11 | kibala
# Processing Record 2 of Set 11 | nefteyugansk
# Processing Record 3 of Set 11 | tateyama
# Processing Record 4 of Set 11 | kjollefjord
# Processing Record 5 of Set 11 | peleduy
# Processing Record 6 of Set 11 | ngaoundere
# City not found. Skipping...
# Processing Record 7 of Set 11 | yulara
# Processing Record 8 of Set 11 | pizarro
# Processing Record 9 of Set 11 | vanimo
# Processing Record 10 of Set 11 | saint-joseph
# Processing Record 11 of Set 11 | honningsvag
# Processing Record 12 of Set 11 | portlethen
# Processing Record 13 of Set 11 | holme
# Processing Record 14 of Set 11 | makaha
# Processing Record 15 of Set 11 | annau
# Processing Record 16 of Set 11 | lethem
# Processing Record 17 of Set 11 | mariakani
# Processing Record 18 of Set 11 | riyadh
# Processing Record 19 of Set 11 | zlobin
# Processing Record 20 of Set 11 | maroua
# Processing Record 21 of Set 11 | bara
# Processing Record 22 of Set 11 | luau
# Processing Record 23 of Set 11 | teruel
# Processing Record 24 of Set 11 | haines junction
# Processing Record 25 of Set 11 | westport
# Processing Record 26 of Set 11 | tortoli
# Processing Record 27 of Set 11 | rawson
# Processing Record 28 of Set 11 | sangar
# Processing Record 29 of Set 11 | kuchera
# Processing Record 30 of Set 11 | elliot lake
# Processing Record 31 of Set 11 | northam
# Processing Record 32 of Set 11 | show low
# Processing Record 33 of Set 11 | boa vista
# Processing Record 34 of Set 11 | minsk
# Processing Record 35 of Set 11 | diu
# Processing Record 36 of Set 11 | khiri mat
# Processing Record 37 of Set 11 | neuquen
# Processing Record 38 of Set 11 | markova
# Processing Record 39 of Set 11 | aviles
# Processing Record 40 of Set 11 | surenavan
# Processing Record 41 of Set 11 | nazret
# Processing Record 42 of Set 11 | camacha
# Processing Record 43 of Set 11 | jovellar
# Processing Record 44 of Set 11 | tra vinh
# Processing Record 45 of Set 11 | la paz
# Processing Record 46 of Set 11 | pervomayskoye
# Processing Record 47 of Set 11 | millinocket
# Processing Record 48 of Set 11 | cedar city
# Processing Record 49 of Set 11 | roma
# Processing Record 1 of Set 12 | ozinki
# Processing Record 2 of Set 12 | tiwi
# Processing Record 3 of Set 12 | minamiashigara
# Processing Record 4 of Set 12 | graneros
# Processing Record 5 of Set 12 | eureka
# Processing Record 6 of Set 12 | avera
# Processing Record 7 of Set 12 | parit buntar
# Processing Record 8 of Set 12 | ahuimanu
# Processing Record 9 of Set 12 | moose factory
# Processing Record 10 of Set 12 | sete
# Processing Record 11 of Set 12 | shakawe
# Processing Record 12 of Set 12 | karratha
# Processing Record 13 of Set 12 | ngunguru
# Processing Record 14 of Set 12 | surab
# Processing Record 15 of Set 12 | los llanos de aridane
# Processing Record 16 of Set 12 | jacqueville
# City not found. Skipping...
# Processing Record 17 of Set 12 | santa cruz del sur
# Processing Record 18 of Set 12 | onega
# Processing Record 19 of Set 12 | omboue
# Processing Record 20 of Set 12 | rocha
# Processing Record 21 of Set 12 | manzhouli
# Processing Record 22 of Set 12 | dong xoai
# Processing Record 23 of Set 12 | fort nelson
# Processing Record 24 of Set 12 | flinders
# Processing Record 25 of Set 12 | north bend
# Processing Record 26 of Set 12 | halifax
# Processing Record 27 of Set 12 | ilulissat
# Processing Record 28 of Set 12 | mackay
# Processing Record 29 of Set 12 | vostok
# Processing Record 30 of Set 12 | kushikino
# Processing Record 31 of Set 12 | killin
# Processing Record 32 of Set 12 | abbeville
# City not found. Skipping...
# Processing Record 33 of Set 12 | broken hill
# ------------------------------
# Data Retrieval Complete
# ------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City":city_two,
    "Cloudiness":cloudinesses,
    "Country":countries,
    "Date":dates,
    "Humidity":humidities,
    "Lat":lats,
    "Lng":lngs,
    "Max Temp":max_temps,
    "Wind Speed":wind_speeds
}

# %%
weather_dataframe = pd.DataFrame(weather_dict)
weather_dataframe.head()
# Out:
#             City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0  mar del plata           0      AR  1567648654        57 -46.43  -67.52
# 1       hermanus           3      ZA  1567648654        60 -34.42   19.24
# 2      bathsheba          40      BB  1567648654        78  13.22  -59.52
# 3         albany           1      US  1567648551       100  42.65  -73.75
# 4           sibu          75      MY  1567648654        74   2.29  111.83
#
#    Max Temp  Wind Speed
# 0     32.37        7.85
# 1     57.00        8.01
# 2     82.40       13.87
# 3     66.20        6.93
# 4     84.20        2.24

# %%
#write to file
weather_dataframe.to_csv(output_data_file)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Max Temp"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Max Temperature (08/04/19)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("../Latitude_vs_Temperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Humidity"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Humidity (08/04/19)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.ylim(15,105)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("../Latitude_vs_Humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Cloudiness"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Cloudiness (08/04/19)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("../Latitude_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_dataframe["Lat"],weather_dataframe["Wind Speed"],edgecolors="black",facecolors="skyblue")
plt.title("City Latitude vs. Wind Speed (08/04/19)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.ylim(-2,34)
plt.grid (b=True,which="major",axis="both",linestyle="-",color="lightgrey")
plt.savefig("../Latitude_vs_Wind Speed.png")
plt.show()
